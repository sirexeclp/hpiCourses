# %% [markdown]
# ## Concrete steps
# ### Imports

# %%
#%% imports
import requests
from lxml import html, etree
import pandas as pd
from urllib.parse import urljoin
import numpy as np
import pickle
import re

#%%
def get(url):
	"""Uses HTTP-GET to request a webresource and converts the result into html-object."""
	result = sessionRequests.get(url
		,headers=dict(referer = url))
	return html.fromstring(result.content)

# %% [markdown]
# ### Crawl the [main hpi courses website]("https://hpi.de/studium/lehrveranstaltungen") to obtain a list of courselists (eg. Bachelor, Master courses, etc.)

# %%
#%%
sessionRequests = requests.session()

baseURL = "https://hpi.de/studium/lehrveranstaltungen"

# %%
def getLVOverwievs(url) -> dict:
	"""crawls the main hpi courses website to obtain a list of courselists (eg. Bachelor, Master courses, etc.) """
	lvSuperList = get(url)
	lvOverviews = lvSuperList.xpath("//h1[contains(text(),'Lehrveranstaltungen')]//following-sibling::ul//a")
	return {x.text:x.get("href") for x in lvOverviews}

lvOverviews = getLVOverwievs(baseURL)

#expand to full path
lvOverviews = list(map(lambda x:urljoin(baseURL,x),lvOverviews.values()))
lvOverviews
# Out:
# ['https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba.html',
#  'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma.html',
#  'https://hpi.de/studium/lehrveranstaltungen/digital-health.html',
#  'https://hpi.de/studium/lehrveranstaltungen/data-engineering.html',
#  'https://hpi.de/studium/lehrveranstaltungen/soft-skills.html',
#  'https://hpi.de/entrepreneurship/veranstaltungen/it-entrepreneurship-vorlesung.html',
#  'https://hpi.de/studium/lehrveranstaltungen/design-thinking.html']

# %% [markdown]
# ### Crawl each table-page with courses and returns a dict with coursename and URL to coursepage.

# %%
def extractDictOfCourses(url):
	"""Crawls a table-page with courses and returns a dict coursename and URL to coursepage """
	courseListPage = get(url)
	return {item.text.strip(): urljoin(url,item.get("href")) for item in
		 courseListPage.xpath("//div[@id = 'content']//table//tr//td[1]//a")}

#list of Courses
listOfCourses = list (map(extractDictOfCourses,lvOverviews))
listOfCourses
# Out:
# [{'3D-Computergrafik I': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-3d-computergrafik-i.html',
#   'Algorithmic Problem Solving': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-algorithmic-problem-solving.html',
#   'Betriebssysteme I': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-betriebssysteme-i.html',
#   'Building Interactive Devices': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-building-interactive-devices.html',
#   'D-School Advanced Track': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-d-school-advanced-track.html',
#   'D-School Basic Track': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-d-school-basic-track.html',
#   'D-School First Track: Introduction to Design Thinking: From Inspirations to Ideas': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-d-school-first-track-introduction-to-design-thinking-from-inspirations-to.html',
#   'Datenbanksysteme II': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-datenbanksysteme-ii.html',
#   'Digitale Bildverarbeitung': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-digitale-bildverarbeitung.html',
#   'Einführung in Software Analytics': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-einfuehrung-in-software-analytics.html',
#   'Einführung in die Programmiertechnik I': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-einfuehrung-in-die-programmiertechnik-i.html',
#   'Fachspezifisches Englisch (Level 1)': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-fachspezifisches-englisch-level-1.html',
#   'Fachspezifisches Englisch (Level 2)': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-fachspezifisches-englisch-level-2.html',
#   'Grundlagen digitaler Systeme': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-grundlagen-digitaler-systeme.html',
#   'HCI Project Seminar: Personal Fabrication, Vitual reality, and Haptics': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-hci-project-seminar-personal-fabrication-vitual-reality-and-haptics.html',
#   'Internet Security - Weaknesses and Targets': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-internet-security-weaknesses-and-targets.html',
#   'Lerntechniken und Strategien zur Prüfungsvorbereitung': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-lerntechniken-und-strategien-zur-pruefungsvorbereitung.html',
#   'Mathematik I - Diskrete Strukturen und Logik': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-mathematik-i-diskrete-strukturen-und-logik.html',
#   'Modellierung I': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-modellierung-i.html',
#   'POIS (Prozessorientierte Informationssysteme)': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-pois-prozessorientierte-informationssysteme.html',
#   'Probability Theory': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-probability-theory.html',
#   'Programmierung von Benutzerschnittstellen': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-programmierung-von-benutzerschnittstellen.html',
#   'Projektentwicklung und - management: Prozess': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-projektentwicklung-und-management-prozess.html',
#   'Projektentwicklung und -management': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-projektentwicklung-und-management.html',
#   'Projektentwicklung und- Management: Teammanagement und Softskills in Projekten': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-projektentwicklung-und-management-teammanagement-und-softskills-in-projek.html',
#   'Recht für Ingenieure I': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-recht-fuer-ingenieure-i-1.html',
#   'Recht für Ingenieure II': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-recht-fuer-ingenieure-ii.html',
#   'Softwarearchitektur': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-softwarearchitektur.html',
#   'Softwaretechnik II - Agile Software Development in Large Teams': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-softwaretechnik-ii-agile-software-development-in-large-teams.html',
#   'Studienbegleitendes Seminar': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-studienbegleitendes-seminar.html',
#   'Theoretische Informatik I': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-theoretische-informatik-i.html',
#   'Webentwicklung mit Web Frameworks': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-webentwicklung-mit-web-frameworks.html',
#   'Wirtschaftliche Grundlagen I': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-wirtschaftliche-grundlagen-i.html',
#   'Überzeugend Präsentieren - Der erste Eindruck zählt': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ba/lehrveranstaltung/course/0/wintersemester-20182019-ueberzeugend-praesentieren-der-erste-eindruck-zaehlt.html'},
#  {'Academic Writing for Science (Fachspezifisches Englisch III)': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-academic-writing-for-science-fachspezifisches-englisch-iii.html',
#   'Advanced Planning for Self-Aware Systems': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-advanced-planning-for-self-aware-systems.html',
#   'Advanced Probability Theory': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-advanced-probability-theory.html',
#   'Algorithmix': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-algorithmix.html',
#   'Approximation Algorithms': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-approximation-algorithms.html',
#   'Blockchain Technology in BPM': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-blockchain-technology-in-bpm.html',
#   'Business Etikette - HPI-Charm-School': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-business-etikette-hpi-charm-school.html',
#   'Computational Geometry': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-computational-geometry.html',
#   'D-School Advanced Track': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-d-school-advanced-track.html',
#   'D-School Basic Track': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-d-school-basic-track.html',
#   'D-School First Track: Introduction to Design Thinking: From Inspirations to Ideas': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-d-school-first-track-introduction-to-design-thinking-from-inspirations-to.html',
#   'Data Management for Digital Health': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-data-management-for-digital-health.html',
#   'Data Preparation for Science': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-data-preparation-for-science.html',
#   'Deep Learning für Text Mining': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-deep-learning-fuer-text-mining.html',
#   'Designing Communication - Communicating Designs': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-designing-communication-communicating-designs.html',
#   'Develop your own Database': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-develop-your-own-database.html',
#   'Distributed Data Management': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-distributed-data-management.html',
#   'Einführung in Software Analytics (MA)': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-einfuehrung-in-software-analytics-ma.html',
#   'Embedded Operating Systems for Internet of Things': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-embedded-operating-systems-for-internet-of-things.html',
#   'Führung und Verantwortung': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-fuehrung-und-verantwortung.html',
#   'Global Team-Based Innovation': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-global-team-based-innovation.html',
#   'Global Team-Based Innovation - Coaching Research': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-global-team-based-innovation-coaching-research.html',
#   'HCI Project Seminar: Virtual reality, Personal Fabrication, and Haptics': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-hci-project-seminar-virtual-reality-personal-fabrication-and-haptics.html',
#   'Health Information Systems I': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-health-information-systems-i.html',
#   'IBM Power Systems': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-ibm-power-systems.html',
#   'IT-Entrepreneurship': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-it-entrepreneurship.html',
#   'IT-Recht': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-it-recht.html',
#   'Konflikt- und Kommunikationsmanagement': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-konflikt-und-kommunikationsmanagement.html',
#   'Machine Intelligence with Deep Learning': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-machine-intelligence-with-deep-learning.html',
#   'Management Essentials': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-management-essentials.html',
#   'Maximierung der Modularität in großen Graphen': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-maximierung-der-modularitaet-in-grossen-graphen.html',
#   'Methoden der Forschung': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-methoden-der-forschung.html',
#   'Methods of Cloud Computing': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-methods-of-cloud-computing.html',
#   'Modern Algorithm Theory': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-modern-algorithm-theory.html',
#   'Modern Infrastructures for Scalable Learning Environments': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-modern-infrastructures-for-scalable-learning-environments.html',
#   'Network Security in Practice': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-network-security-in-practice.html',
#   'Personal Management Skills': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-personal-management-skills.html',
#   'Recommender Systems': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-recommender-systems.html',
#   'Reverse-Engineering': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-reverse-engineering.html',
#   'Runtime Verification: Online Testing Powered by Formal Methods': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-runtime-verification-online-testing-powered-by-formal-methods.html',
#   'Safety-Critical Systems: From Predictable Systems to Autonomous AI': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-safety-critical-systems-from-predictable-systems-to-autonomous-ai.html',
#   'Securing Cloud Storages': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-securing-cloud-storages.html',
#   'Selbstführung und Persönlichkeit': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-selbstfuehrung-und-persoenlichkeit.html',
#   'Social Media Mining': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-social-media-mining.html',
#   'Social Network Analysis in Practice': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-social-network-analysis-in-practice.html',
#   'Software Testen, Analysieren und Verifizieren': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-software-testen-analysieren-und-verifizieren.html',
#   'Spatial Data Engineering': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-spatial-data-engineering.html',
#   'Trends in Betriebssystemen (Forschungsseminar)': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-trends-in-betriebssystemen-forschungsseminar.html',
#   'Trends in Bioinformatics': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-trends-in-bioinformatics.html',
#   'Trends und Konzepte in der Softwareindustrie II': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-trends-und-konzepte-in-der-softwareindustrie-ii.html',
#   'Unternehmenssimulation strategisches Management': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-unternehmenssimulation-strategisches-management.html',
#   'Visualization Algorithms & Techniques': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-visualization-algorithms-techniques.html',
#   'Überzeugend Präsentieren - Noch besser auftreten (Fortgeschrittene)': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-ueberzeugend-praesentieren-noch-besser-auftreten-fortgeschrittene.html'},
#  {'Advanced Probability Theory': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-advanced-probability-theory.html',
#   'Algorithmix': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-algorithmix.html',
#   'Approximation Algorithms': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-approximation-algorithms.html',
#   'Business Process Analysis in Healthcare': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-business-process-analysis-in-healthcare.html',
#   'Computational Geometry': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-computational-geometry.html',
#   'D-School Advanced Track': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-d-school-advanced-track.html',
#   'D-School Basic Track': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-d-school-basic-track.html',
#   'D-School First Track: Introduction to Design Thinking: From Inspirations to Ideas': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-d-school-first-track-introduction-to-design-thinking-from-inspirations-to.html',
#   'Data Management for Digital Health': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-data-management-for-digital-health.html',
#   'Data Preparation for Science': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-data-preparation-for-science.html',
#   'Deep Learning für Text Mining': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-deep-learning-fuer-text-mining.html',
#   'Designing Communication - Communicating Designs': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-designing-communication-communicating-designs.html',
#   'Digital Health System and Data Interoperability': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-digital-health-system-and-data-interoperability.html',
#   'Distributed Data Management': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-distributed-data-management.html',
#   'Embedded Operating Systems for Internet of Things': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-embedded-operating-systems-for-internet-of-things.html',
#   'Ethical Issues in Digital Health': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-ethical-issues-in-digital-health.html',
#   'Fundamentals of Programming': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-fundamentals-of-programming.html',
#   'HCI Project Seminar: Virtual reality, Personal Fabrication, and Haptics': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-hci-project-seminar-virtual-reality-personal-fabrication-and-haptics.html',
#   'Health Information Systems I': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-health-information-systems-i.html',
#   'Health and Disease Core Competencies': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-health-and-disease-core-competencies.html',
#   'Healthcare Fundamentals and Digital Health Trends (Understanding Healthcare)': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-healthcare-fundamentals-and-digital-health-trends-understanding-healthcare.html',
#   'IT-Entrepreneurship': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-it-entrepreneurship.html',
#   'Introduction to IT Systems': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-introduction-to-it-systems.html',
#   'Machine Intelligence with Deep Learning': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-machine-intelligence-with-deep-learning.html',
#   'Management Essentials': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-management-essentials.html',
#   'Modern Algorithm Theory': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-modern-algorithm-theory.html',
#   'Network Security in Practice': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-network-security-in-practice.html',
#   'Safety-Critical Systems: From Predictable Systems to Autonomous AI': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-safety-critical-systems-from-predictable-systems-to-autonomous-ai.html',
#   'Securing Cloud Storages': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-securing-cloud-storages.html',
#   'Social Media Mining': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-social-media-mining.html',
#   'Trends in Bioinformatics': 'https://hpi.de/studium/lehrveranstaltungen/digital-health/lehrveranstaltung/course/0/wintersemester-20182019-trends-in-bioinformatics.html'},
#  {'Academic Writing for Science (Fachspezifisches Englisch III)': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-academic-writing-for-science-fachspezifisches-englisch-iii.html',
#   'Advanced Probability Theory': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-advanced-probability-theory.html',
#   'Algorithmix': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-algorithmix.html',
#   'Approximation Algorithms': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-approximation-algorithms.html',
#   'Blockchain Technology in BPM': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-blockchain-technology-in-bpm.html',
#   'Business Etikette - HPI-Charm-School': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-business-etikette-hpi-charm-school.html',
#   'Computational Geometry': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-computational-geometry.html',
#   'D-School Advanced Track': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-d-school-advanced-track.html',
#   'D-School Basic Track': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-d-school-basic-track.html',
#   'D-School First Track: Introduction to Design Thinking: From Inspirations to Ideas': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-d-school-first-track-introduction-to-design-thinking-from-inspirations-to.html',
#   'Data Management for Digital Health': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-data-management-for-digital-health.html',
#   'Data Preparation for Science': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-data-preparation-for-science.html',
#   'Deep Learning für Text Mining': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-deep-learning-fuer-text-mining.html',
#   'Designing Communication - Communicating Designs': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-designing-communication-communicating-designs.html',
#   'Develop your own Database': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-develop-your-own-database.html',
#   'Distributed Data Management': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-distributed-data-management.html',
#   'Ethik und Gesellschaft: datenbasierte Verhaltensvorhersage und -steuerung': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-ethik-und-gesellschaft-datenbasierte-verhaltensvorhersage-und-steuerung.html',
#   'Führung und Verantwortung': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-fuehrung-und-verantwortung.html',
#   'HCI Project Seminar: Virtual reality, Personal Fabrication, and Haptics': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-hci-project-seminar-virtual-reality-personal-fabrication-and-haptics.html',
#   'Health Information Systems I': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-health-information-systems-i.html',
#   'IBM Power Systems': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-ibm-power-systems.html',
#   'IT-Entrepreneurship': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-it-entrepreneurship.html',
#   'IT-Recht': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-it-recht.html',
#   'Konflikt- und Kommunikationsmanagement': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-konflikt-und-kommunikationsmanagement.html',
#   'Machine Intelligence with Deep Learning': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-machine-intelligence-with-deep-learning.html',
#   'Management Essentials': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-management-essentials.html',
#   'Methoden der Forschung': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-methoden-der-forschung.html',
#   'Modern Algorithm Theory': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-modern-algorithm-theory.html',
#   'Network Security in Practice': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-network-security-in-practice.html',
#   'Personal Management Skills': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-personal-management-skills.html',
#   'Privatheit im digitalen Zeitalter - Privacy Design aus einer ethischen Perspektive': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-privatheit-im-digitalen-zeitalter-privacy-design-aus-einer-ethischen-pers.html',
#   'Recommender Systems': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-recommender-systems.html',
#   'Securing Cloud Storages': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-securing-cloud-storages.html',
#   'Selbstführung und Persönlichkeit': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-selbstfuehrung-und-persoenlichkeit.html',
#   'Social Media Mining': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-social-media-mining.html',
#   'Social Network Analysis in Practice': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-social-network-analysis-in-practice.html',
#   'Spatial Data Engineering': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-spatial-data-engineering.html',
#   'Trends und Konzepte in der Softwareindustrie II': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-trends-und-konzepte-in-der-softwareindustrie-ii.html',
#   'Unternehmenssimulation strategisches Management': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-unternehmenssimulation-strategisches-management.html',
#   'Visualization Algorithms & Techniques': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-visualization-algorithms-techniques.html',
#   'Überzeugend Präsentieren - Noch besser auftreten (Fortgeschrittene)': 'https://hpi.de/studium/lehrveranstaltungen/data-engineering/lehrveranstaltung/course/0/wintersemester-20182019-ueberzeugend-praesentieren-noch-besser-auftreten-fortgeschrittene.html'},
#  {'Soft-Skills-Kolloquium': 'https://hpi.de/das-hpi/veranstaltungen/hpi-veranstaltungen/soft-skills-kolloquium.html',
#   'Studierendenklubs': 'https://hpi.de/das-hpi/personen/studierende/studentenklubs.html'},
#  {},
#  {'D-School Advanced Track': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-d-school-advanced-track.html',
#   'D-School Basic Track': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-d-school-basic-track.html',
#   'D-School First Track: Introduction to Design Thinking: From Inspirations to Ideas': 'https://hpi.de/studium/lehrveranstaltungen/it-systems-engineering-ma/lehrveranstaltung/course/0/wintersemester-20182019-d-school-first-track-introduction-to-design-thinking-from-inspirations-to.html'}]

# %% [markdown]
# ### Combine the list of dicts to one big list, which only contains URLs.

# %%
def combineLinkList(linkList):
	"""combines the list of dicts to one big list, which only contains URLs"""
	return [courseLink for subject in 
		linkList for courseLink in subject.values()]

urlsToCrawl = combineLinkList(listOfCourses)

# %% [markdown]
# ### Downloads the individual course websites.

# %%
#%%
#import time
#def downloadCourseSites(urls,delay = 0.1):
#	"""downloads the individual course websites """
#	result = []
#	for item in urls:
#		result.append(get(item))
#		print(f"got {item.split('/')[-1]}")
#		time.sleep(delay)
#	return result

#courseWebsites = downloadCourseSites (urlsToCrawl)
#%% save/load crawled websites with pickle

# courseWebsitesString = [etree.tostring(x) for x in courseWebsites]

# with open("websites.pkl","wb") as file:
# 	pickle.dump(courseWebsitesString, file)

# %% [markdown]
# ### or use local copy instead

# %%
#%%
"""uncomment this to load the locally saved websites"""
with open("websites.pkl","rb") as file:
	cws = pickle.load(file)

courseWebsites = [html.fromstring(x) for x in cws]

# %% [markdown]
# ### Extract data from course website
# 5. Use XPATH to extract information from the course websites. Store it in a dict.
# 6. If coursewebsite links to a coursesite from the chair, download the chair site as well.
# 7. Finds all Links, on the websites that destination ends with the given fileextension (eg. '.pdf', '.pptx').

# %%
#%%
def findAllFiles(secondPage, secondURL, fileExtension):
    """Finds all Links, on given website at given url that destination ends with
    the given fileextension."""
    assert secondPage, "Second page must not be 'None'."
    return [urljoin(secondURL,x) for x in 
        secondPage.xpath(f"//a[contains(@href,'{fileExtension}')]/@href")]

#%%
"""lets create a list of dicts where each dict holds infos about one course"""
allCourses = []
for site,url in zip(courseWebsites, urlsToCrawl):
    course = {}
    #get the main heading of the coursesite which should contain the coursename and semester
    fullTitle = site.xpath("//h1[1]/text()")[0]
    #use this regex to split coursename and semester
    matches = re.search(r"(.*)\((.*)\)",fullTitle)

    if matches:
        course["Name"] = matches[1]
        course["Semester"] = matches[2]
    else:
        #if regex did not match anything, just use the whole headline as coursetitle and 
        #assume theres no semester given
        course["Name"] = fullTitle
    course["URL"] = url
    #find the link after '...Website', which should be the link to the 2nd course page
    secondURL = site.xpath("//div/text()[contains(.,'Website')]/following-sibling::i/a/@href")
    secondURL = urljoin(url, secondURL[0]) if secondURL else None
    secondPage = None
    if secondURL:
        course["secondURL"] = secondURL
        secondPage = get(secondURL)
        course["files"] = findAllFiles(secondPage, secondURL, ".pdf")
    
    #Margaux Anrechenbarkeit
    anItSe = site.xpath("//div[contains(text(),'IT-Systems Engineering MA')]//following-sibling::ul//li//text()")
    str_anItSe = ", ".join(anItSe)
    course["Anrechenbarkeit Master ItSe"] = str_anItSe
    
    anDE = site.xpath("//div[contains(text(),'Data Engineering MA')]//following-sibling::ul//li//text()")
    str_anDE = ", ".join(anDE)
    course["Anrechenbarkeit Master DE"] = str_anDE
    
    anDH = site.xpath("//div[contains(text(),'Digital Health MA')]//following-sibling::ul//li//text()")
    str_anDH = ", ".join(anDH)
    course["Anrechenbarkeit Master DH"] = str_anDH
    
    anB = site.xpath("//div[contains(text(),'IT-Systems Engineering BA')]//following-sibling::ul//li//text()")
    str_anB = ", ".join(anB)
    course["Anrechenbarkeit Bachelor ItSe"] = str_anB  
    
    #extract all basic infos from a list on the course page
    for item in site.xpath("//h2[contains(text(),'Allgemeine Information')]/following-sibling::ul[1]//li//text()"):
        if len(item.split(":")) == 2:
            key,val = item.split(":")
            course[key] = val.strip()
    allCourses.append(course)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The behavior of this method will change in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.
#   """

# %% [markdown]
# ### Create Pandas dataframe

# %%
#%%
"""Create a DataFrame from the dicts"""
df = pd.DataFrame(columns=["Name"
    #,"Website"
    ,"Belegungsart"
    ,"Benotet"
    ,"ECTS"
    ,"Einschreibefrist"
    ,"Lehrform"
    ,"Lehrsprache"
    ,"Semesterwochenstunden"
    ,"Anrechenbarkeit Bachelor ItSe"
    ,"Anrechenbarkeit Master ItSe"
    ,"Anrechenbarkeit Master DE"
    ,"Anrechenbarkeit Master DH"
    ,"URL"
    ,"files"
    ,"secondURL"
    ])
df = df.append(allCourses,ignore_index = True)
df[df.Name.str.contains("Preparation")]
# Out:
#     Anrechenbarkeit Bachelor ItSe  \
# 46
# 96
# 129
#
#                              Anrechenbarkeit Master DE  \
# 46   DATA-Konzepte und Methoden, DATA-Techniken und...
# 96   DATA-Konzepte und Methoden, DATA-Techniken und...
# 129  DATA-Konzepte und Methoden, DATA-Techniken und...
#
#                              Anrechenbarkeit Master DH  \
# 46   APAD-Concepts and Methods, APAD-Technologies a...
# 96   APAD-Concepts and Methods, APAD-Technologies a...
# 129  APAD-Concepts and Methods, APAD-Technologies a...
#
#                            Anrechenbarkeit Master ItSe      Belegungsart  \
# 46   OSIS-Konzepte und Methoden, OSIS-Spezialisieru...  Wahlpflichtmodul
# 96   OSIS-Konzepte und Methoden, OSIS-Spezialisieru...  Wahlpflichtmodul
# 129  OSIS-Konzepte und Methoden, OSIS-Spezialisieru...  Wahlpflichtmodul
#
#     Benotet ECTS Einschreibefrist        Lehrform Lehrsprache  \
# 46       Ja    6       26.10.2018  Projektseminar     Deutsch
# 96       Ja    6       26.10.2018  Projektseminar     Deutsch
# 129      Ja    6       26.10.2018  Projektseminar     Deutsch
#
#     Maximale Teilnehmerzahl                           Name  \
# 46                      NaN  Data Preparation for Science
# 96                      NaN  Data Preparation for Science
# 129                     NaN  Data Preparation for Science
#
#                      Semester Semesterwochenstunden  \
# 46   Wintersemester 2018/2019                     4
# 96   Wintersemester 2018/2019                     4
# 129  Wintersemester 2018/2019                     4
#
#                                                    URL  \
# 46   https://hpi.de/studium/lehrveranstaltungen/it-...
# 96   https://hpi.de/studium/lehrveranstaltungen/dig...
# 129  https://hpi.de/studium/lehrveranstaltungen/dat...
#
#                                                  files  \
# 46   [https://hpi.de/fileadmin/user_upload/fachgebi...
# 96   [https://hpi.de/fileadmin/user_upload/fachgebi...
# 129  [https://hpi.de/fileadmin/user_upload/fachgebi...
#
#                                              secondURL
# 46   https://hpi.de/naumann/teaching/teaching/ws-18...
# 96   https://hpi.de/naumann/teaching/teaching/ws-18...
# 129  https://hpi.de/naumann/teaching/teaching/ws-18...

# %% [markdown]
# ### Use pandas built in methods to remove duplicates

# %%
#remove duplicates, but ignore files and URL column
duplicatesRemoved = df.drop_duplicates(df.columns.difference(["files","URL"]))
duplicatesRemoved
dup2 = df.drop_duplicates(subset =["Name"])

# %%
print(f"with duplicates: {len(df)}")
print(f"with duplicates removed: {len(duplicatesRemoved)}")
print(len(dup2))

merged = duplicatesRemoved.columns.difference(["files","URL"]).merge(dup2, indicator=True, how='outer')
merged[merged['_merge'] == 'right_only']
# Out:
# with duplicates: 164
# with duplicates removed: 99
# 96
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-50d23f451e81> in <module>()
#       3 print(len(dup2))
#       4
# ----> 5 merged = duplicatesRemoved.merge(dup2, indicator=True, how='outer')
#       6 merged[merged['_merge'] == 'right_only']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#    4720                      right_on=right_on, left_index=left_index,
#    4721                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 4722                      copy=copy, indicator=indicator)
#    4723
#    4724     def round(self, decimals=0, *args, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
#      53                          copy=copy, indicator=indicator)
# ---> 54     return op.get_result()
#      55
#      56
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     567                 self.left, self.right)
#     568
# --> 569         join_index, left_indexer, right_indexer = self._get_join_info()
#     570
#     571         ldata, rdata = self.left._data, self.right._data
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     732         else:
#     733             (left_indexer,
# --> 734              right_indexer) = self._get_join_indexers()
#     735
#     736             if self.right_index:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(self)
#     711                                   self.right_join_keys,
#     712                                   sort=self.sort,
# --> 713                                   how=self.how)
#     714
#     715     def _get_join_info(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#     980
#     981     # get left & right join labels and num. of levels at each location
# --> 982     llab, rlab, shape = map(list, zip(* map(fkeys, left_keys, right_keys)))
#     983
#     984     # get flat i8 keys from label lists
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _factorize_keys(lk, rk, sort)
#    1403     rizer = klass(max(len(lk), len(rk)))
#    1404
# -> 1405     llab = rizer.factorize(lk)
#    1406     rlab = rizer.factorize(rk)
#    1407
#
# pandas\_libs\hashtable.pyx in pandas._libs.hashtable.Factorizer.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# TypeError: unhashable type: 'list'

# %%
duplicatesRemoved[duplicatesRemoved.Name.str.contains("D-School Basic Track")]
# Out:
#     Anrechenbarkeit Bachelor ItSe Anrechenbarkeit Master DE  \
# 5                 Design Thinking    Design Thinking Basics
# 162
#
#     Anrechenbarkeit Master DH Anrechenbarkeit Master ItSe      Belegungsart  \
# 5       Design Thinking Basic       Design Thinking Basic  Wahlpflichtmodul
# 162                              Design Thinking Advanced
#
#     Benotet ECTS                                Einschreibefrist  \
# 5        Ja    9                                      31.01.2019
# 162      Ja    9  31. Juli 2018 für das Wintersemester 2018/2019
#
#               Lehrform Lehrsprache Maximale Teilnehmerzahl  \
# 5    Projekt / Seminar         NaN                      80
# 162  Projekt / Seminar         NaN                      80
#
#                       Name                  Semester Semesterwochenstunden  \
# 5    D-School Basic Track   Wintersemester 2018/2019                     6
# 162  D-School Basic Track        Sommersemester 2018                     6
#
#                                                    URL files secondURL
# 5    https://hpi.de/studium/lehrveranstaltungen/it-...   NaN       NaN
# 162  https://hpi.de/studium/lehrveranstaltungen/it-...   NaN       NaN

# %%
list(duplicatesRemoved[duplicatesRemoved.Name.str.contains("Preparation")].files)
# Out:
# [['https://hpi.de/fileadmin/user_upload/fachgebiete/naumann/lehre/WS2018/Data_preparation_for_science/01_Intro_DQ_DataPrep_Felix.pdf',
#   'https://hpi.de/fileadmin/user_upload/fachgebiete/naumann/lehre/WS2018/Data_preparation_for_science/Task_proposals.pdf',
#   'https://hpi.de/fileadmin/user_upload/fachgebiete/naumann/lehre/WS2018/Data_preparation_for_science/03_task_announcement.pdf']]

# %%
duplicatesRemoved[(duplicatesRemoved["Lehrform"].str.contains("Vorlesung", na=False))
                      & (duplicatesRemoved.ECTS.astype(float) == 6) & duplicatesRemoved["Anrechenbarkeit Master ItSe"]]
# Out:
#    Anrechenbarkeit Bachelor ItSe  \
# 36
# 37
# 38
# 41
# 45
# 50
# 52
# 66
# 74
# 79
#
#                             Anrechenbarkeit Master DE  \
# 36  DATA-Konzepte und Methoden, DATA-Techniken und...
# 37  SCAL-Konzepte und Methode, SCAL-Techniken und ...
# 38  SCAL-Konzepte und Methode, SCAL-Techniken und ...
# 41  DATA-Konzepte und Methoden, DATA-Techniken und...
# 45  CODS-Konzepte und Methoden, CODS-Techniken und...
# 50                                    Datenmanagement
# 52
# 66
# 74
# 79
#
#                             Anrechenbarkeit Master DH  \
# 36                                SCAD-Specialization
# 37  SCAD-Concepts and Methods, SCAD-Technologies a...
# 38                                SCAD-Specialization
# 41                                SCAD-Specialization
# 45  SCAD-Concepts and Methods, SCAD-Technologies a...
# 50  APAD-Concepts and Methods, APAD-Technologies a...
# 52  SCAD-Concepts and Methods, SCAD-Technologies a...
# 66
# 74  APAD-Concepts and Methods, APAD-Technologies a...
# 79
#
#                           Anrechenbarkeit Master ItSe      Belegungsart  \
# 36  ISAE-Konzepte und Methoden, ISAE-Techniken und...  Wahlpflichtmodul
# 37  ITSE-Analyse, ITSE-Entwurf, ITSE-Konstruktion,...  Wahlpflichtmodul
# 38  ISAE-Konzepte und Methoden, ISAE-Techniken und...  Wahlpflichtmodul
# 41  ISAE-Konzepte und Methoden, ISAE-Spezialisieru...  Wahlpflichtmodul
# 45  ITSE-Analyse, ITSE-Entwurf, ITSE-Konstruktion,...  Wahlpflichtmodul
# 50  ITSE-Analyse, ITSE-Entwurf, ITSE-Konstruktion,...  Wahlpflichtmodul
# 52  ITSE-Analyse, ITSE-Entwurf, ITSE-Konstruktion,...  Wahlpflichtmodul
# 66  ITSE-Analyse, ITSE-Entwurf, ITSE-Konstruktion,...  Wahlpflichtmodul
# 74  ITSE-Analyse, ITSE-Entwurf, ITSE-Konstruktion,...  Wahlpflichtmodul
# 79  OSIS-Konzepte und Methoden, OSIS-Spezialisieru...  Wahlpflichtmodul
#
#    Benotet ECTS Einschreibefrist             Lehrform Lehrsprache  \
# 36      Ja    6       26.10.2018    Vorlesung / Übung    Englisch
# 37      Ja    6       26.10.2018    Vorlesung / Übung         NaN
# 38      Ja    6       26.10.2018    Vorlesung / Übung     Deutsch
# 41      Ja    6       26.10.2018    Vorlesung / Übung     Deutsch
# 45      Ja    6       26.10.2018    Vorlesung / Übung    Englisch
# 50      Ja    6       26.10.2018    Vorlesung / Übung     Deutsch
# 52      Ja    6       26.10.2018  Vorlesung / Projekt     Deutsch
# 66      Ja    6       26.10.2018            Vorlesung     Deutsch
# 74      Ja    6       26.10.2018    Vorlesung / Übung     Deutsch
# 79      Ja    6       26.10.2018  Vorlesung / Projekt     Deutsch
#
#    Maximale Teilnehmerzahl                                               Name  \
# 36                      10                       Advanced Probability Theory
# 37                     NaN                                       Algorithmix
# 38                      30                          Approximation Algorithms
# 41                      30                            Computational Geometry
# 45                     NaN                Data Management for Digital Health
# 50                     NaN                       Distributed Data Management
# 52                      30  Embedded Operating Systems for Internet of Thi...
# 66                     NaN                        Methods of Cloud Computing
# 74                     NaN  Safety-Critical Systems: From Predictable Syst...
# 79                      20     Software Testen, Analysieren und Verifizieren
#
#                     Semester Semesterwochenstunden  \
# 36  Wintersemester 2018/2019                     4
# 37  Wintersemester 2018/2019                     4
# 38  Wintersemester 2018/2019                     4
# 41  Wintersemester 2018/2019                     4
# 45  Wintersemester 2018/2019                     4
# 50  Wintersemester 2018/2019                     4
# 52  Wintersemester 2018/2019                     4
# 66  Wintersemester 2018/2019                     4
# 74  Wintersemester 2018/2019                     4
# 79  Wintersemester 2018/2019                     4
#
#                                                   URL  \
# 36  https://hpi.de/studium/lehrveranstaltungen/it-...
# 37  https://hpi.de/studium/lehrveranstaltungen/it-...
# 38  https://hpi.de/studium/lehrveranstaltungen/it-...
# 41  https://hpi.de/studium/lehrveranstaltungen/it-...
# 45  https://hpi.de/studium/lehrveranstaltungen/it-...
# 50  https://hpi.de/studium/lehrveranstaltungen/it-...
# 52  https://hpi.de/studium/lehrveranstaltungen/it-...
# 66  https://hpi.de/studium/lehrveranstaltungen/it-...
# 74  https://hpi.de/studium/lehrveranstaltungen/it-...
# 79  https://hpi.de/studium/lehrveranstaltungen/it-...
#
#                                                 files  \
# 36                                                 []
# 37                                                 []
# 38                                                 []
# 41                                                 []
# 45  [https://hpi.de/fileadmin/user_upload/fachgebi...
# 50  [https://hpi.de/fileadmin/user_upload/fachgebi...
# 52  [https://www.dcl.hpi.uni-potsdam.de/teaching/E...
# 66  [https://www.dcl.hpi.uni-potsdam.de/teaching/m...
# 74                                                NaN
# 79                                                NaN
#
#                                             secondURL
# 36  https://hpi.de/friedrich/teaching/ws18/probabi...
# 37  https://hpi.de//friedrich/teaching/ws18/algori...
# 38  https://hpi.de//friedrich/teaching/ws18/approx...
# 41  https://hpi.de/friedrich/teaching/ws18/algorit...
# 45  https://hpi.de/digital-health-center/teaching/...
# 50  https://hpi.de/naumann/teaching/teaching/ws-18...
# 52  https://www.dcl.hpi.uni-potsdam.de/teaching/Em...
# 66  https://www.dcl.hpi.uni-potsdam.de/teaching/mo...
# 74                                                NaN
# 79                                                NaN

# %%
duplicatesRemoved[(duplicatesRemoved.Belegungsart == "Pflichtmodul")]
# Out:
#           Anrechenbarkeit Bachelor ItSe  \
# 2                       Betriebssysteme
# 9                  Programmiertechnik I
# 13                     Digitale Systeme
# 17                         Mathematik I
# 18                       Modellierung I
# 22
# 23   Projektentwicklung und -management
# 24   Projektentwicklung und -management
# 25                Rechtliche Grundlagen
# 26                Rechtliche Grundlagen
# 27                 Software-Architektur
# 30            Theoretische Informatik I
# 33           Wirtschaftliche Grundlagen
# 57
# 73
# 90
# 99
# 102
# 103
# 108
#
#                              Anrechenbarkeit Master DE  \
# 2
# 9
# 13
# 17
# 18
# 22
# 23
# 24
# 25
# 26
# 27
# 30
# 33
# 57   CODS-Konzepte und Methoden, CODS-Techniken und...
# 73
# 90
# 99
# 102
# 103
# 108
#
#                              Anrechenbarkeit Master DH  \
# 2
# 9
# 13
# 17
# 18
# 22
# 23
# 24
# 25
# 26
# 27
# 30
# 33
# 57           Software Architectures for Digital Health
# 73
# 90   Digital Health Business and Process Transforma...
# 99           Software Architectures for Digital Health
# 102      Ethics, Law and Compliance for Digital Health
# 103                        Fundamentals of Programming
# 108                           Principles of IT Systems
#
#                            Anrechenbarkeit Master ItSe  Belegungsart Benotet  \
# 2                                                       Pflichtmodul      Ja
# 9                                                       Pflichtmodul      Ja
# 13                                                      Pflichtmodul      Ja
# 17                                                      Pflichtmodul      Ja
# 18                                                      Pflichtmodul      Ja
# 22                                                      Pflichtmodul      Ja
# 23                                                      Pflichtmodul      Ja
# 24                                                      Pflichtmodul      Ja
# 25                                                      Pflichtmodul      Ja
# 26                                                      Pflichtmodul      Ja
# 27                                                      Pflichtmodul      Ja
# 30                                                      Pflichtmodul      Ja
# 33                                                      Pflichtmodul      Ja
# 57   BPET-Konzepte und Methoden, BPET-Techniken und...  Pflichtmodul      Ja
# 73   ITSE-Analyse, ITSE-Entwurf, ITSE-Konstruktion,...  Pflichtmodul      Ja
# 90                                                      Pflichtmodul      Ja
# 99                                                      Pflichtmodul      Ja
# 102                                                     Pflichtmodul      Ja
# 103                                                     Pflichtmodul      Ja
# 108                                                     Pflichtmodul      Ja
#
#     ECTS Einschreibefrist             Lehrform Lehrsprache  \
# 2      6       26.10.2018    Vorlesung / Übung     Deutsch
# 9      6       26.10.2018    Vorlesung / Übung     Deutsch
# 13     6       26.10.2018    Vorlesung / Übung     Deutsch
# 17     6       26.10.2018    Vorlesung / Übung     Deutsch
# 18     6       26.10.2018    Vorlesung / Übung     Deutsch
# 22     6       26.10.2018         Blockseminar     Deutsch
# 23     6       26.10.2018         Blockseminar         NaN
# 24     6                          Blockseminar     Deutsch
# 25     3       26.10.2018            Vorlesung     Deutsch
# 26     3       26.10.2018            Vorlesung         NaN
# 27     6       26.10.2018            Vorlesung     Deutsch
# 30     6       26.10.2018    Vorlesung / Übung         NaN
# 33     3       26.10.2018            Vorlesung     Deutsch
# 57     3       26.10.2018  Vorlesung / Seminar    Englisch
# 73     6       26.10.2018    Seminar / Projekt     Deutsch
# 90     3       26.10.2018  Vorlesung / Seminar    Englisch
# 99     3       26.10.2018  Vorlesung / Seminar    Englisch
# 102    3       26.10.2018            Vorlesung         NaN
# 103    6       26.10.2018  Vorlesung / Projekt    Englisch
# 108    6       26.10.2018    Vorlesung / Übung         NaN
#
#     Maximale Teilnehmerzahl  \
# 2                       NaN
# 9                       NaN
# 13                      NaN
# 17                      NaN
# 18                      NaN
# 22                       20
# 23                       20
# 24                       20
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 30                      NaN
# 33                      NaN
# 57                       40
# 73                      NaN
# 90                      NaN
# 99                       40
# 102                      30
# 103                     NaN
# 108                      20
#
#                                                   Name  \
# 2                                   Betriebssysteme I
# 9              Einführung in die Programmiertechnik I
# 13                       Grundlagen digitaler Systeme
# 17       Mathematik I - Diskrete Strukturen und Logik
# 18                                     Modellierung I
# 22       Projektentwicklung und - management: Prozess
# 23                 Projektentwicklung und -management
# 24   Projektentwicklung und- Management: Teammanage...
# 25                             Recht für Ingenieure I
# 26                            Recht für Ingenieure II
# 27                                Softwarearchitektur
# 30                          Theoretische Informatik I
# 33                       Wirtschaftliche Grundlagen I
# 57                       Health Information Systems I
# 73   Runtime Verification: Online Testing Powered b...
# 90            Business Process Analysis in Healthcare
# 99    Digital Health System and Data Interoperability
# 102                  Ethical Issues in Digital Health
# 103                       Fundamentals of Programming
# 108                        Introduction to IT Systems
#
#                      Semester Semesterwochenstunden  \
# 2    Wintersemester 2018/2019                     4
# 9    Wintersemester 2018/2019                     4
# 13   Wintersemester 2018/2019                     4
# 17   Wintersemester 2018/2019                     4
# 18   Wintersemester 2018/2019                     4
# 22   Wintersemester 2018/2019                     4
# 23   Wintersemester 2018/2019                     4
# 24   Wintersemester 2018/2019                     4
# 25   Wintersemester 2018/2019                     2
# 26   Wintersemester 2018/2019                     2
# 27   Wintersemester 2018/2019                     4
# 30   Wintersemester 2018/2019                     4
# 33   Wintersemester 2018/2019                     2
# 57   Wintersemester 2018/2019                     2
# 73   Wintersemester 2018/2019                     4
# 90   Wintersemester 2018/2019                     2
# 99   Wintersemester 2018/2019                     2
# 102  Wintersemester 2018/2019                     2
# 103  Wintersemester 2018/2019                     4
# 108  Wintersemester 2018/2019                     4
#
#                                                    URL  \
# 2    https://hpi.de/studium/lehrveranstaltungen/it-...
# 9    https://hpi.de/studium/lehrveranstaltungen/it-...
# 13   https://hpi.de/studium/lehrveranstaltungen/it-...
# 17   https://hpi.de/studium/lehrveranstaltungen/it-...
# 18   https://hpi.de/studium/lehrveranstaltungen/it-...
# 22   https://hpi.de/studium/lehrveranstaltungen/it-...
# 23   https://hpi.de/studium/lehrveranstaltungen/it-...
# 24   https://hpi.de/studium/lehrveranstaltungen/it-...
# 25   https://hpi.de/studium/lehrveranstaltungen/it-...
# 26   https://hpi.de/studium/lehrveranstaltungen/it-...
# 27   https://hpi.de/studium/lehrveranstaltungen/it-...
# 30   https://hpi.de/studium/lehrveranstaltungen/it-...
# 33   https://hpi.de/studium/lehrveranstaltungen/it-...
# 57   https://hpi.de/studium/lehrveranstaltungen/it-...
# 73   https://hpi.de/studium/lehrveranstaltungen/it-...
# 90   https://hpi.de/studium/lehrveranstaltungen/dig...
# 99   https://hpi.de/studium/lehrveranstaltungen/dig...
# 102  https://hpi.de/studium/lehrveranstaltungen/dig...
# 103  https://hpi.de/studium/lehrveranstaltungen/dig...
# 108  https://hpi.de/studium/lehrveranstaltungen/dig...
#
#                                                  files  \
# 2    [https://www.dcl.hpi.uni-potsdam.de/teaching/B...
# 9                                                  NaN
# 13                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 30   [http://www-cc.cs.uni-saarland.de/media/lectur...
# 33                                                 NaN
# 57                                                 NaN
# 73                                                 NaN
# 90                                                 NaN
# 99                                                 NaN
# 102                                                NaN
# 103                                                NaN
# 108                                                NaN
#
#                                            secondURL
# 2    https://www.dcl.hpi.uni-potsdam.de/teaching/BS/
# 9                                                NaN
# 13                                               NaN
# 17                                               NaN
# 18                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 30   https://hpi.de/friedrich/teaching/ws18/ti1.html
# 33                                               NaN
# 57                                               NaN
# 73                                               NaN
# 90                                               NaN
# 99                                               NaN
# 102                                              NaN
# 103                                              NaN
# 108                                              NaN

# %% [markdown]
# ### Save the result as .csv file.

# %%
duplicatesRemoved.to_csv("output.csv")

# %% [markdown]
# ### continue with OpenRefine
